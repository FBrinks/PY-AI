# %% [markdown]
# # Matplotlib
# Read the tutorials: https://matplotlib.org/stable/users/explain/quick_start.html and https://matplotlib.org/stable/tutorials/pyplot.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
# Objekt-orienterad plottning, denna är den rekommenderade.
# Pylot-plottning kan också göras, även om den inte är den officiellt rekommenderade används den ibland för att på ett rakt och enkelt sätt visa upp data.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
# figure = Objektet som skapas vid initieringen och som innehåller allt som krävs för att visualisera data. 
# Det fungerar som behållare för en eller flera Axes och andra visuella element. Beroende på vilka funktioner som används 
# fylls figure med innehåll och kan sedan visas eller sparas.

# axes = Det område (ett koordinatsystem) inom figure där datan ritas upp. En figure kan innehålla flera axes, t.ex. i subplots. 
# Det är i axes som grafer, etiketter och andra element placeras.

# axis = De individuella axlarna (x och y) inom ett axes-objekt. De bestämmer skalan, märkning och riktningen för datan som visualiseras.

# artist = Gemensam benämning på alla visuella objekt i matplotlib, t.ex. linjer, texter, figurer, axlar – allt som faktiskt ritas upp 
# och syns.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
# Numpy-arrayer, eller datatyper som kan omvandlas till arrayer. Till exempel datatyper från Pandas. 
# Dessa kan omvandlas innan till numpy-arrayer för att fungera med matplotlib.

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
x = np.linspace(-4, 4, 50)
y = x**2

fig, ax = plt.subplots()
ax.set(title="Object-oriented Plot", xlabel="X-axis", ylabel="Y-axis")
ax.plot(x, y)

# %%
x = np.linspace(-4, 4, 50)
y = x**2

plt.plot(x, y)
plt.title("Pyplot approach")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show() # Behövs egentligen inte vid körning i Jupyter notebook

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

fig, axs = plt.subplots(1, 2, figsize=(18, 6))

axs[0].set(title="Scatter plot")
axs[0].scatter(random_data_x, random_data_y)

axs[1].set(title="Bar plot", xlabel="Fruit name", ylabel="Amount")
axs[1].bar(x=names, height=values)
# Out:
# <BarContainer object of 5 artists>
